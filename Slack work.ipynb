# %%
thor2 = ['Chris Hemsworth', 'Natalie Portman', 'Tom Hiddleston', 'Kat Dennings', 'Anthony Hopkins', 'Jaimie Alexander', 'Idris Elba']

# %%
ragnarok = ['Chris Hemsworth', 'Tessa Thompson', 'Cate Blanchett', 'Tom Hiddleston', 'Mark Ruffalo', 'Jeff Goldblum', 'Karl Urban', 'Idris Elba', 'Anthony Hopkins']

# %%
com_actors = list(set(thor2).intersection(set(ragnarok)))

# %%
com_actors
# Out:
# ['Tom Hiddleston', 'Chris Hemsworth', 'Idris Elba', 'Anthony Hopkins']

# %%
word = "funnuf"

# %%
word == word[::-1]
# Out:
# True

# %%
def palindrome(pp):
    return pp == pp[::-1]

# %%
palindrome("kayak")
# Out:
# True

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(101)
x = 30*np.random.randn(1000)
fig, ax = plt.subplots(figsize=(8,6))
ax.hist(x, 20, color="red")

ax.set_title("Random Histogram", fontsize = 25)

ax.set_ylabel("Number of Random Numbers", fontsize = 20)

ax.set_xlabel("Random Number", fontsize = 20)

ax.tick_params(length=6, which="both", labelsize=15);

# %%
import time as tm
import numpy as np
import math as mt

# %%
start = tm.time()
x=0
while x <= 100000000:
    x += 1
    2**.5
end = tm.time()
print(end-start)
# Out:
# 10.773166418075562

# %%
x=1
while x<=10000000:
    y=x
    if y**.5 != np.sqrt(y):
        print(y,False,1, (y**.5-np.sqrt(y)))
    
    if mt.sqrt(y) != np.sqrt(y):
        print(y,False,2, (mt.sqrt(y)-np.sqrt(y)))

    x+=1
# Out:
# 343 False 1 -3.552713678800501e-15
# 525 False 1 3.552713678800501e-15
# 550 False 1 -3.552713678800501e-15
# 971 False 1 -3.552713678800501e-15
# 1372 False 1 -7.105427357601002e-15
# 2026 False 1 -7.105427357601002e-15
# 2100 False 1 7.105427357601002e-15
# 2200 False 1 -7.105427357601002e-15
# 2463 False 1 -7.105427357601002e-15
# 3884 False 1 -7.105427357601002e-15
# 5050 False 1 1.4210854715202004e-14
# 5488 False 1 -1.4210854715202004e-14
# 5705 False 1 1.4210854715202004e-14
# 5974 False 1 -1.4210854715202004e-14
# 8104 False 1 -1.4210854715202004e-14
# 8400 False 1 1.4210854715202004e-14
# 8451 False 1 -1.4210854715202004e-14
# 8800 False 1 -1.4210854715202004e-14
# 9852 False 1 -1.4210854715202004e-14
# 10799 False 1 1.4210854715202004e-14
# 10923 False 1 -1.4210854715202004e-14
# 11271 False 1 -1.4210854715202004e-14
# 12994 False 1 -1.4210854715202004e-14
# 13058 False 1 -1.4210854715202004e-14
# 13614 False 1 -1.4210854715202004e-14
# ...

# %%
start = tm.time()
x=0
while x <= 100000000:
    x += 1
    np.sqrt(2)
end = tm.time()
print(end-start)
# Out:
# 113.27398490905762

# %%
# Out:
# 1.0
# 1.4142135623730951
# 1.7320508075688772
# 2.0
# 2.23606797749979
# 2.449489742783178
# 2.6457513110645907
# 2.8284271247461903
# 3.0
# 3.1622776601683795

# %%
start = tm.time()
x=0
while x <= 100000000:
    x += 1
    mt.sqrt(2)
end = tm.time()
print(end-start)
# Out:
# 26.801286935806274

# %%
# Out:
# 1.0
# 1.4142135623730951
# 1.7320508075688772
# 2.0
# 2.23606797749979
# 2.449489742783178
# 2.6457513110645907
# 2.8284271247461903
# 3.0
# 3.1622776601683795
